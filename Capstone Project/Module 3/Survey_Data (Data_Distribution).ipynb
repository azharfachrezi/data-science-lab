# %% [markdown]
# # **FINDING HOW DATA DISTRIBUTED**

# %% [markdown]
# #### IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### LOAD THE DATASET

# %%
# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# %%
# Set option for maximum columns view
pd.set_option("display.max_columns", None)

# %% [markdown]
# #### EXAMINE THE STRUCTURE OF DATA

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
# (65437, 114)

# %%
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %%
print(df.dtypes.to_string())

# %% [markdown]
# ---

# %% [markdown]
# #### HANDLE MISSING DATA

# %%
print(df.isna().sum().to_string())

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
# ---Handle Missing Values in RemoteWork---
print("RemoteWork Column Summary:\n")
print(f"Number of missing values: {df['RemoteWork'].isna().sum()}")
print(f"Data type: {df['RemoteWork'].dtypes}")
print(df['RemoteWork'].unique())

df['RemoteWork'] = df['RemoteWork'].fillna('Unknown')

# Verify
print(f"\nNumber of missing values after imputing: {df['RemoteWork'].isna().sum()}")
# Out:
# RemoteWork Column Summary:
#
# Number of missing values: 10631
# Data type: object
# ['Remote' nan 'In-person' 'Hybrid (some remote, some in-person)']
#
# Number of missing values after imputing: 0

# %%
# ---Handle Missing Values in EdLevel---
print("EdLevel Column Summary:\n")
print(f"Number of missing values: {df['EdLevel'].isna().sum()}")
print(f"Data type: {df['EdLevel'].dtypes}")
print(df['EdLevel'].unique())

df['EdLevel'] = df['EdLevel'].fillna('Unknown')

# Verify
print(f"\nNumber of missing values after imputing: {df['EdLevel'].isna().sum()}")
# Out:
# EdLevel Column Summary:
#
# Number of missing values: 4653
# Data type: object
# ['Primary/elementary school'
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'
#  'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'
#  'Some college/university study without earning a degree'
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'
#  'Professional degree (JD, MD, Ph.D, Ed.D, etc.)'
#  'Associate degree (A.A., A.S., etc.)' 'Something else' nan]
#
# Number of missing values after imputing: 0

# %%
# ---Handle Missing Values in JobSat---
print("JobSat Column Summary:\n")
print(f"Number of missing values: {df['JobSat'].isna().sum()}")
print(f"Data type: {df['JobSat'].dtypes}")
print(df['JobSat'].unique())

df['JobSat'] = df['JobSat'].fillna(-1)

# Verify
print(f"\nNumber of missing values after imputing: {df['JobSat'].isna().sum()}")
# Out:
# JobSat Column Summary:
#
# Number of missing values: 36311
# Data type: float64
# [nan  8.  5. 10.  6.  9.  4.  7.  3.  2.  1.  0.]
#
# Number of missing values after imputing: 0

# %%
# ---Handle Missing Values in YearsCodePro---
print("YearsCodePro Column Summary:\n")
print(f"Number of missing values: {df['YearsCodePro'].isna().sum()}")
print(f"Data type: {df['YearsCodePro'].dtypes}")
print(df['YearsCodePro'].unique())

# Replace map for string value
replace_map = {
    'Less than 1 year' : 0,     # following the logic
    'More than 50 years': 51    
}

# Replace value according to replace_map
df['YearsCodePro'] = df['YearsCodePro'].replace(replace_map)

# Convert dtype to numeric
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# ---MASK for ACCURATE FILLING---
# People who are students/not employed AND represent NO form of employment
student_unemp= df['Employment'].str.contains("Student|Not employed", case=False, na=False)

# People who are Employed or Independent Contractor
is_worker = df['Employment'].str.contains("Employed|Independent contractor|Freelancer", case=False, na=False)

# Candidates for "0" experience:
# They are students group, but they are NOT in worker group
zero_experience = student_unemp & (~is_worker)

# ---FILL MISSING VALUES---
# Fill "0" experience candidates using filter
df.loc[zero_experience, 'YearsCodePro'] = df.loc[zero_experience, 'YearsCodePro'].fillna(0)

# Fill everyone else with median value
df['YearsCodePro'] = df['YearsCodePro'].fillna(df['YearsCodePro'].median())

# Verify
print(f"\nNumber of missing values after imputing: {df['YearsCodePro'].isna().sum()}")
# Out:
# YearsCodePro Column Summary:
#
# Number of missing values: 13827
# Data type: float64
# [nan 17. 27.  7. 11. 25. 12. 10.  3.  0. 18. 37. 15. 20.  6.  2. 16.  8.
#  14.  4. 45.  1. 24. 29.  5. 30. 26.  9. 33. 13. 35. 23. 22. 31. 19. 21.
#  28. 34. 32. 40. 50. 39. 44. 42. 41. 36. 38. 51. 43. 47. 48. 46. 49.]
#
# Number of missing values after imputing: 0

# %% [markdown]
# ---

# %% [markdown]
# #### ANALYZE KEY COLUMNS

# %%
# JobSat distribution

# Filter out -1 (Unknown) values
applicable = df[df['JobSat'] >= 0]

plt.figure(figsize=(12,6))
sns.histplot(data=applicable, x='JobSat', discrete=True, kde=True, color='purple', legend=False)
plt.title("Job Satisfaction Distribution")
plt.xlabel("Satisfaction Scale (0-10)")
plt.ylabel('Count')

plt.show()

# %%
# Years Code Pro value counts
plt.figure(figsize=(12,6))

sns.histplot(data=df, x='YearsCodePro', bins=50, kde=True, hue='YearsCodePro', legend=False)
plt.title("Professional Coding Experience Distribution")
plt.xlabel('Years')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### PROGRAMMING LANGUAGE ANALYSIS

# %%
# ---PROGRAMMING LANGUAGE HAVE WORKED WITH---

# Check for missing values
print(f"Number of missing values: {df['LanguageHaveWorkedWith'].isna().sum()}")

# Fill with placeholder 'Unknown'
df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].fillna('Unknown')

# Verify
print(f"Number of missing values after imputing: {df['LanguageHaveWorkedWith'].isna().sum()}")
# Out:
# Number of missing values: 5692
# Number of missing values after imputing: 0

# %%
# ---PROGRAMMING LANGUAGE WANT TO WORK WITH---

# Check for missing values
print(f"Number of missing values: {df['LanguageWantToWorkWith'].isna().sum()}")

# Fill with placeholder 'Unknown'
df['LanguageWantToWorkWith'] = df['LanguageWantToWorkWith'].fillna('Unknown')

# Verify
print(f"Number of missing values after imputing: {df['LanguageWantToWorkWith'].isna().sum()}")
# Out:
# Number of missing values: 9685
# Number of missing values after imputing: 0

# %%
df[['LanguageHaveWorkedWith','LanguageWantToWorkWith']].sample(10)
# Out:
#                                   LanguageHaveWorkedWith  \
# 10345                                         C++;Python
# 23966  C;C++;Go;HTML/CSS;Java;JavaScript;Perl;PHP;Pyt...
# 19002                                         JavaScript
# 33278  Bash/Shell (all shells);C;C++;Go;Perl;PHP;Pyth...
# 16786              HTML/CSS;JavaScript;Python;TypeScript
# 62846                                               Dart
# 11855  Assembly;Bash/Shell (all shells);HTML/CSS;Java...
# 195         Dart;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 7807     HTML/CSS;JavaScript;Lisp;Perl;Python;TypeScript
# 52858  C++;HTML/CSS;JavaScript;MATLAB;Python;SQL;Type...
#
#                                   LanguageWantToWorkWith
# 10345                               C++;Haskell;Python;R
# 23966  Elixir;HTML/CSS;Java;JavaScript;PHP;Python;Rub...
# 19002              JavaScript;Python;Rust;SQL;TypeScript
# 33278                                       C++;Perl;SQL
# ...

# %% [markdown]
# >Since the values of these 2 columns are combination from several programming language and delimited with ";". I'll have to seperate them first using `.explode` method for the best result.

# %%
# Create function for practice use
def get_language_percentage(df, column_name):
    # Create temporary dataframe
    temp_df = df[df[column_name] != 'Unknown'].copy()
    total_resp = len(temp_df)

    # Explode and count
    explode = temp_df[column_name].str.split(";").explode()
    count = explode.value_counts()

    # Convert to percentage
    return (count / total_resp) * 100

# Get the data from both sides
pct_have = get_language_percentage(df, 'LanguageHaveWorkedWith')
pct_want = get_language_percentage(df, 'LanguageWantToWorkWith')

# Merge into one dataframe
comparison = pd.DataFrame({
    'Worked_With (%)' : pct_have,
    'Want_to_Work_With (%)' : pct_want,
}).sort_values('Worked_With (%)', ascending=False)

# Calculate the "Growth Potential" (The Gap)
comparison['Difference (%)'] = comparison['Want_to_Work_With (%)'] - comparison['Worked_With (%)']

comparison.head().round(2)
# Out:
#             Worked_With (%)  Want_to_Work_With (%)  Difference (%)
# JavaScript            62.75                  42.64          -20.11
# HTML/CSS              53.25                  37.17          -16.09
# Python                51.42                  44.93           -6.49
# SQL                   51.35                  40.18          -11.18
# TypeScript            38.75                  36.30           -2.45

# %%
# Visualize to compare
# Let's set limit for top 15 language to keep the chart readable
top_15 = comparison.head(15).reset_index().rename(columns={'index': 'Language'})

melted = top_15.melt(id_vars= 'Language',
                     value_vars=['Worked_With (%)', 'Want_to_Work_With (%)'],
                     var_name='Category',
                     value_name='Percentage'
)

plt.figure(figsize=(12,6))
sns.barplot(x='Percentage', y='Language', hue='Category', data=melted, palette='viridis')

plt.title('Reality vs Expectation: Programming Language')
plt.xlabel('Percentage of Respondents (%)')
plt.ylabel('Language')

plt.show()

# %%
from matplotlib_venn import venn2

# 1. Identify the Most Popular Language (Current) to focus the Venn Diagram on
# We'll re-use the 'explode' logic to find the top one
all_langs = df['LanguageHaveWorkedWith'].str.split(';', expand=True).stack()
top_lang = all_langs.value_counts().idxmax() # Likely 'JavaScript' or 'Python'

# 2. Create Sets for that Top Language
# set_have: Rows that include the top language in 'HaveWorkedWith'
# set_want: Rows that include the top language in 'WantToWorkWith'
set_have = set(df[df['LanguageHaveWorkedWith'].str.contains(top_lang, regex=False, na=False)].index)
set_want = set(df[df['LanguageWantToWorkWith'].str.contains(top_lang, regex=False, na=False)].index)

# 3. Plot the Venn Diagram
plt.figure(figsize=(8, 8))
try:
    # Calculate overlaps manually for the label
    only_have = len(set_have - set_want)
    only_want = len(set_want - set_have)
    both = len(set_have & set_want)
    
    # Draw Venn
    v = venn2(subsets=(only_have, only_want, both), set_labels=('Currently Use', 'Want to Use'))
    
    # Custom coloring
    v.get_patch_by_id('10').set_color('tomato')  # Burnout (Have but don't want)
    v.get_patch_by_id('01').set_color('skyblue') # New Interest (Want but don't have)
    v.get_patch_by_id('11').set_color('mediumseagreen') # Retention (Have & Want)
    
    plt.title(f"The 'Love/Hate' Relationship with {top_lang}")
    plt.show()

except ImportError:
    print("⚠️ 'matplotlib-venn' library not found. Skipping Venn Diagram.")

# ---------------------------------------------------------
# 4. Side-by-Side Pie Charts (Market Share)
# ---------------------------------------------------------

def get_top_5_market_share(column):
    # Explode, count, and take top 5
    counts = df[column].str.split(';').explode().value_counts().head(5)
    return counts

have_counts = get_top_5_market_share('LanguageHaveWorkedWith')
want_counts = get_top_5_market_share('LanguageWantToWorkWith')

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# Plot 'Have' Pie
axes[0].pie(have_counts, labels=have_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
axes[0].set_title('Current Market Share (Top 5 Used)')

# Plot 'Want' Pie
axes[1].pie(want_counts, labels=want_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
axes[1].set_title('Future Market Share (Top 5 Wanted)')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### ANALYZE REMOTEWORK TRENDS

# %%
 # Handle missing values for Country
df['Country'] = df['Country'].fillna('Unknown')

# verify
print(f"Number of missing values: {df['Country'].isna().sum()}")
# Out:
# Number of missing values: 0

# %%
# Filter top 10 Country based on count of survey respondent
top10_country = df.loc[df['Country'] != 'Unknown', 'Country'].value_counts().head(10)

cr_df = df.loc[(df['Country'].isin(top10_country.index)) & (df['RemoteWork'] != 'Unknown'), ['Country', 'RemoteWork']]
cr_df['Country'] = cr_df['Country'].replace({'United Kingdom of Great Britain and Northern Ireland' : 'United Kingdom'})

# Create crosstab for Country and RemoteWork in top 10 country
crosstab = pd.crosstab(index=cr_df['Country'], columns=cr_df['RemoteWork'], normalize='index')


# Create Heatmap
plt.figure(figsize=(12,6))

sns.heatmap(crosstab, annot=True, fmt='.1%', cmap='YlGnBu', cbar=True, cbar_kws={'label' : 'Percentage'})

plt.title('Remote Work Distribution by Country')
plt.xlabel('Type of Remote Works')
plt.ylabel('Country')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### CORRELATION BETWEEN JOB SATISFACTION AND EXPERIENCE

# %%
jse_df = df.loc[df['JobSat'] >= 0, ['JobSat', 'YearsCodePro']]


plt.figure(figsize=(12,6))

sns.scatterplot(data=jse_df, x='YearsCodePro', y='JobSat', hue='JobSat')

plt.title('Correlation Between Job Satisfaction vs Experience')
plt.xlabel('Professional Coding Experience (Years)')
plt.ylabel('Job Satisfaction (0-10)')

plt.show()

print(f"Correlation Coefficient: {jse_df['JobSat'].corr(jse_df['YearsCodePro'])}")
# Out:
# Correlation Coefficient: 0.10457920271329973

# %% [markdown]
# There's no correlation or very weak positive correlation, since the correlation coefficient close to zero (0.1)

# %% [markdown]
# ---

# %% [markdown]
# ####  Cross-tabulation Analysis (Employment vs. Education Level)

# %%
# Create Function for cleaning edlevel values
def clean_edlevel(text):
    text = str(text)
    if 'Primary' in text:
        return 'Primary School'
    elif 'Bachelor' in text:
        return 'Bachelor'
    elif 'Master' in text:
        return 'Master'
    elif 'Secondary school' in text or 'high school' in text:
        return 'High School'
    elif 'Some college' in text:
        return 'Some College'
    elif 'Professional' in text:
        return 'Professional'
    elif 'Associate' in text:
        return 'Associate'
    else:
        return 'Other'

# Create a seperate dataframe
emped_df = df[['EdLevel', 'Employment']].copy()

# Make new columns for clean values
emped_df['EdLevel_Clean'] = emped_df['EdLevel'].apply(clean_edlevel)
emped_df['Employment_Clean'] = emped_df['Employment'].str.split(';').str[0]

# Cross-tabulation edlevel and employment
crosstab = pd.crosstab(index=emped_df['EdLevel_Clean'], columns=emped_df['Employment_Clean'], normalize='index')

# %%
# Visualize with stacked Bar Chart

# Reorder edlevel logic
edlevel_order = [
    'Primary School', 'High School', 'Some College',
    'Associate', 'Bachelor','Master', 'Professional', 'Other' 
]

current_order = [x for x in edlevel_order if x in crosstab.index]
crosstab_sorted = crosstab.reindex(current_order)

# Plotting
crosstab_sorted.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')

plt.title('Employment Distribution by Education Level', fontsize=16)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Proportion (0-1)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Employment Status', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **Summary:**

# %% [markdown]
# I've practiced:
#
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#
# - Comparing programming languages respondents have worked with versus those they want to work with.
#
# - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.
